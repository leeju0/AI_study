# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
import networkx as nx
import seaborn as sns
import pickle

# %%
#임상데이터를 불러와서, 첫번째 열 제거하고, bcr_patient_barcode를 인덱스로 설정한다.

df_clinic = pd.read_csv('/home/lee/home/clinic_patient/COAD_clinic_patient.csv')

df_clinic.set_index('bcr_patient_barcode', inplace=True)
df_clinic
# Out:
#                     additional_studies tumor_tissue_site  \
# bcr_patient_barcode
# TCGA-3L-AA1B                       NaN             Colon
# TCGA-4N-A93T                       NaN             Colon
# TCGA-4T-AA8H                       NaN             Colon
# TCGA-5M-AAT4                       NaN             Colon
# TCGA-5M-AAT6                       NaN             Colon
# ...                                ...               ...
# TCGA-QL-A97D                       NaN             Colon
# TCGA-RU-A8FL                       NaN             Colon
# TCGA-SS-A7HO                       NaN             Colon
# TCGA-T9-A92H                       NaN             Colon
# TCGA-WS-AB45                       NaN             Colon
#
#                                  histological_type other_dx  gender  \
# bcr_patient_barcode
# TCGA-3L-AA1B                  Colon Adenocarcinoma       No  FEMALE
# TCGA-4N-A93T                  Colon Adenocarcinoma       No    MALE
# TCGA-4T-AA8H         Colon Mucinous Adenocarcinoma       No  FEMALE
# TCGA-5M-AAT4                  Colon Adenocarcinoma       No    MALE
# TCGA-5M-AAT6                  Colon Adenocarcinoma       No  FEMALE
# ...                                            ...      ...     ...
# TCGA-QL-A97D                  Colon Adenocarcinoma       No  FEMALE
# TCGA-RU-A8FL                  Colon Adenocarcinoma       No    MALE
# TCGA-SS-A7HO                  Colon Adenocarcinoma       No  FEMALE
# TCGA-T9-A92H                  Colon Adenocarcinoma       No    MALE
# TCGA-WS-AB45         Colon Mucinous Adenocarcinoma       No  FEMALE
#
#                     vital_status  days_to_birth  days_to_last_known_alive  \
# bcr_patient_barcode
# TCGA-3L-AA1B               Alive       -22379.0                       NaN
# TCGA-4N-A93T               Alive       -24523.0                       NaN
# TCGA-4T-AA8H               Alive       -15494.0                       NaN
# TCGA-5M-AAT4                Dead       -27095.0                       NaN
# TCGA-5M-AAT6                Dead       -14852.0                       NaN
# ...                          ...            ...                       ...
# TCGA-QL-A97D               Alive       -30914.0                       NaN
# TCGA-RU-A8FL               Alive       -18975.0                       NaN
# TCGA-SS-A7HO               Alive       -16416.0                       NaN
# TCGA-T9-A92H               Alive       -30058.0                       NaN
# TCGA-WS-AB45               Alive            NaN                       NaN
#
#                      days_to_death  days_to_last_followup  ...  \
# bcr_patient_barcode                                        ...
# TCGA-3L-AA1B                   NaN                  475.0  ...
# TCGA-4N-A93T                   NaN                  146.0  ...
# TCGA-4T-AA8H                   NaN                  385.0  ...
# TCGA-5M-AAT4                  49.0                    NaN  ...
# TCGA-5M-AAT6                 290.0                    NaN  ...
# ...                            ...                    ...  ...
# TCGA-QL-A97D                   NaN                  666.0  ...
# TCGA-RU-A8FL                   NaN                 1177.0  ...
# TCGA-SS-A7HO                   NaN                 1829.0  ...
# TCGA-T9-A92H                   NaN                  362.0  ...
# TCGA-WS-AB45                   NaN                 2130.0  ...
#
#                     stage_event_system_version stage_event_clinical_stage  \
# bcr_patient_barcode
# TCGA-3L-AA1B                               7th                        NaN
# TCGA-4N-A93T                               7th                        NaN
# TCGA-4T-AA8H                               7th                        NaN
# TCGA-5M-AAT4                               6th                        NaN
# TCGA-5M-AAT6                               6th                        NaN
# ...                                        ...                        ...
# TCGA-QL-A97D                               7th                        NaN
# TCGA-RU-A8FL                               7th                        NaN
# TCGA-SS-A7HO                               7th                        NaN
# TCGA-T9-A92H                               7th                        NaN
# TCGA-WS-AB45                               6th                        NaN
#
#                     stage_event_pathologic_stage stage_event_tnm_categories  \
# bcr_patient_barcode
# TCGA-3L-AA1B                             Stage I                     T2N0M0
# TCGA-4N-A93T                          Stage IIIB                   T4aN1bM0
# TCGA-4T-AA8H                           Stage IIA                     T3N0MX
# TCGA-5M-AAT4                            Stage IV                    T3N0M1b
# TCGA-5M-AAT6                            Stage IV                  T4aN2bM1a
# ...                                          ...                        ...
# TCGA-QL-A97D                             Stage I                     T2N0MX
# TCGA-RU-A8FL                          Stage IIIB                    T3N2aMX
# TCGA-SS-A7HO                           Stage IIB                    T4aN0M0
# TCGA-T9-A92H                           Stage IIA                     T3N0M0
# TCGA-WS-AB45                           Stage IIA                     T3N0MX
#
#                     stage_event_psa stage_event_gleason_grading  \
# bcr_patient_barcode
# TCGA-3L-AA1B                    NaN                         NaN
# TCGA-4N-A93T                    NaN                         NaN
# TCGA-4T-AA8H                    NaN                         NaN
# TCGA-5M-AAT4                    NaN                         NaN
# TCGA-5M-AAT6                    NaN                         NaN
# ...                             ...                         ...
# TCGA-QL-A97D                    NaN                         NaN
# TCGA-RU-A8FL                    NaN                         NaN
# TCGA-SS-A7HO                    NaN                         NaN
# TCGA-T9-A92H                    NaN                         NaN
# TCGA-WS-AB45                    NaN                         NaN
#
#                     stage_event_ann_arbor stage_event_serum_markers  \
# bcr_patient_barcode
# TCGA-3L-AA1B                          NaN                       NaN
# TCGA-4N-A93T                          NaN                       NaN
# TCGA-4T-AA8H                          NaN                       NaN
# TCGA-5M-AAT4                          NaN                       NaN
# TCGA-5M-AAT6                          NaN                       NaN
# ...                                   ...                       ...
# TCGA-QL-A97D                          NaN                       NaN
# TCGA-RU-A8FL                          NaN                       NaN
# TCGA-SS-A7HO                          NaN                       NaN
# TCGA-T9-A92H                          NaN                       NaN
# TCGA-WS-AB45                          NaN                       NaN
#
#                     stage_event_igcccg_stage stage_event_masaoka_stage
# bcr_patient_barcode
# TCGA-3L-AA1B                             NaN                       NaN
# TCGA-4N-A93T                             NaN                       NaN
# TCGA-4T-AA8H                             NaN                       NaN
# TCGA-5M-AAT4                             NaN                       NaN
# TCGA-5M-AAT6                             NaN                       NaN
# ...                                      ...                       ...
# TCGA-QL-A97D                             NaN                       NaN
# TCGA-RU-A8FL                             NaN                       NaN
# TCGA-SS-A7HO                             NaN                       NaN
# TCGA-T9-A92H                             NaN                       NaN
# TCGA-WS-AB45                             NaN                       NaN
#
# [459 rows x 75 columns]

# %%
#분석하고자 하는 컬럼만 남긴다.
df_clinic = df_clinic[['icd_o_3_histology','icd_10','histological_type','kras_mutation_found', 'kras_mutation_codon','braf_gene_analysis_result']]


df_clinic.head(5)
# Out:
#                     icd_o_3_histology icd_10              histological_type  \
# bcr_patient_barcode
# TCGA-3L-AA1B                   8140/3  C18.0           Colon Adenocarcinoma
# TCGA-4N-A93T                   8140/3  C18.2           Colon Adenocarcinoma
# TCGA-4T-AA8H                   8480/3  C18.6  Colon Mucinous Adenocarcinoma
# TCGA-5M-AAT4                   8140/3  C18.2           Colon Adenocarcinoma
# TCGA-5M-AAT6                   8140/3  C18.2           Colon Adenocarcinoma
#
#                     kras_mutation_found  kras_mutation_codon  \
# bcr_patient_barcode
# TCGA-3L-AA1B                        NaN                  NaN
# TCGA-4N-A93T                        NaN                  NaN
# TCGA-4T-AA8H                        NaN                  NaN
# TCGA-5M-AAT4                        NaN                  NaN
# TCGA-5M-AAT6                        NaN                  NaN
#
#                     braf_gene_analysis_result
# bcr_patient_barcode
# TCGA-3L-AA1B                              NaN
# TCGA-4N-A93T                              NaN
# TCGA-4T-AA8H                              NaN
# TCGA-5M-AAT4                              NaN
# TCGA-5M-AAT6                              NaN

# %%
print('사용한 서브타입 : ')
for i in df_clinic.columns:
    print(i)
# Out:
# 사용한 서브타입 :
# icd_o_3_histology
# icd_10
# histological_type
# kras_mutation_found
# kras_mutation_codon
# braf_gene_analysis_result

# %%
#데이터프레임의 각 행을 입력받아 특정 값을 제외한 나머지 값을 dict형태로 변환한다.
# 함수는 row의 각 컬럼과 값을 순회하며 값이 NaN이 아니고 excluded_values 리스트에 없는 경우에만 col: val 쌍으로 포함한다.
def row_to_dict(row):
    excluded_values = [
        '8140/3',
        '8255/3',
        '8010/3', 'C18.9'
          ]
    return {col: val for col, val in row.items() if pd.notna(val) and val not in excluded_values}

# 위 함수실행
row_sets = df_clinic.apply(row_to_dict, axis=1)

# 샘플 : {'컬럼이름': '값', '컬럼이름': '값', ... }
for index, value in row_sets.items():
    print(f'{index}: {value}')
# Out:
# TCGA-3L-AA1B: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-4N-A93T: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-4T-AA8H: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.6', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-5M-AAT4: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-5M-AAT6: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-5M-AATE: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES'}
# TCGA-A6-2670: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2671: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2672: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2674: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.7', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-A6-2675: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2676: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2677: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2678: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2679: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2680: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2681: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2682: {'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-A6-2683: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-A6-2684: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2685: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-2686: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-3807: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-3808: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-3809: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-A6-3810: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-4105: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-4107: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5656: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5657: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5659: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5660: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5661: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5662: {'icd_10': 'C18.5', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-A6-5664: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5665: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'braf_gene_analysis_result': 'Abnormal'}
# TCGA-A6-5666: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-5667: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6137: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6138: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6140: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6141: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6142: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-A6-6648: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-A6-6649: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6650: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6651: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6652: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6653: {'histological_type': 'Colon Adenocarcinoma', 'braf_gene_analysis_result': 'Abnormal'}
# TCGA-A6-6654: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-6780: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-A6-6781: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-A6-6782: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-A565: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.4', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-A6-A566: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.6', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-A6-A567: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-A56B: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-A6-A5ZU: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3488: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3489: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3492: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3494: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3495: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3496: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3502: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3506: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3509: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3510: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3511: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3514: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3516: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3517: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3518: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3519: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3520: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3521: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3522: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3524: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3525: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3526: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3527: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3529: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3530: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3531: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3532: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3534: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3538: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3542: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3543: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3544: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3548: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3549: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3552: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3553: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3554: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3555: {'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3556: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.7'}
# TCGA-AA-3558: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3560: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3561: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3562: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3655: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3660: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3662: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3663: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3664: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3666: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3667: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3672: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3673: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3675: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3678: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3679: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3680: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3681: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3684: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3685: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3688: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3692: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3693: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3695: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3696: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3697: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3710: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3712: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3713: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3715: {'icd_o_3_histology': '8560/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3811: {'icd_o_3_histology': '8574/3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3812: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3814: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3815: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3818: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3819: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3821: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3831: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3833: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3837: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3841: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3842: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3844: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3845: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3846: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3848: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3850: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3851: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3852: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3854: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3855: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3856: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3858: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3860: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3861: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3862: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3864: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3866: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3867: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3869: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3870: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3872: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3875: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3877: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.4', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3930: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3939: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3941: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3947: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3949: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3950: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3952: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3955: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3956: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3966: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-3967: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3968: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3970: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3971: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3972: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3973: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3975: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3976: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3977: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3979: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3980: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3982: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3984: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3986: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3989: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-3994: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A004: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00A: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00D: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00E: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00F: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00J: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A00K: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00L: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00N: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A00O: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00Q: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00R: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00U: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00W: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A00Z: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A010: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A017: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01C: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01D: {'icd_o_3_histology': '8480/3', 'icd_10': 'C19', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A01F: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01G: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A01I: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01K: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01P: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01Q: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01R: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A01S: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01T: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01V: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01X: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A01Z: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A022: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A024: {'icd_10': 'C18.6', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A029: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02E: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02F: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02H: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02J: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02K: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02O: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02R: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02W: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A02Y: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AA-A03F: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AA-A03J: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-5900: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AD-6548: {'icd_10': 'C18.5', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6888: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6889: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6890: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6895: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6899: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AD-6901: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6963: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-6964: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'braf_gene_analysis_result': 'Normal'}
# TCGA-AD-6965: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-A5EJ: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AD-A5EK: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AM-5820: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AM-5821: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AU-3779: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AU-6004: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-4070: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-AY-4071: {'icd_10': 'C18.7'}
# TCGA-AY-5543: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-6196: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-AY-6197: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-6386: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-A54L: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-A69D: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-A71X: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AY-A8YK: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4308: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4313: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4315: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4323: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4614: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4615: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-AZ-4616: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4681: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4682: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-4684: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-5403: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-5407: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6598: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6599: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6600: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6601: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6603: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6605: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6606: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6607: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-AZ-6608: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-5254: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-5255: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-5256: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-5796: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CA-5797: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-6715: {'icd_o_3_histology': '8260/3', 'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-6716: {'icd_o_3_histology': '8260/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-6717: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CA-6718: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CA-6719: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-4947: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-4948: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-4950: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CK-4951: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CK-4952: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CK-5912: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-5913: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'braf_gene_analysis_result': 'Normal'}
# TCGA-CK-5914: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-5915: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-5916: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-6746: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-6747: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CK-6748: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.7', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-CK-6751: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CM-4743: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4744: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4746: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4747: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4748: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.4', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CM-4750: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4751: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-4752: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5341: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5344: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5348: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5349: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5860: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5861: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5862: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-CM-5863: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CM-5864: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-5868: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-CM-6161: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6162: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-CM-6163: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6164: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6165: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6166: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6167: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6168: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6169: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6170: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6171: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6172: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6674: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6675: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6676: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6677: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6678: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-CM-6679: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-CM-6680: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-5537: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-5538: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-5539: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-D5-5540: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-5541: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6529: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6530: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6531: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6532: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6533: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6534: {'icd_o_3_histology': '8480/3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-D5-6535: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6536: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6537: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6538: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6539: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6540: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-D5-6541: {'icd_10': 'C18.5', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6898: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6920: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6922: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6923: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6924: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6926: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6927: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6928: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-D5-6929: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6930: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-D5-6931: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-6932: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-D5-7000: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-DM-A0X9: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A0XD: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 13.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A0XF: {'icd_10': 'C18.7', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 13.0}
# TCGA-DM-A1D0: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1D4: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1D6: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.5', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1D7: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.7', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1D8: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 13.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1D9: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-DM-A1DA: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1DB: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1HA: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A1HB: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.4', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Abnormal'}
# TCGA-DM-A280: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A282: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A285: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.2', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A288: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 13.0}
# TCGA-DM-A28A: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A28C: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-DM-A28E: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A28F: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A28G: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A28H: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-DM-A28K: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.3', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-DM-A28M: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0, 'braf_gene_analysis_result': 'Normal'}
# TCGA-F4-6459: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6460: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6461: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6463: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.4', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-F4-6569: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6570: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6703: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6704: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.7', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-F4-6805: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6806: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6807: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6808: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6809: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6854: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-F4-6855: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-F4-6856: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-G4-6293: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6294: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6295: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6297: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6298: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6299: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6302: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-G4-6303: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-G4-6304: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6306: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6307: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6309: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6310: {'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6311: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6314: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO', 'braf_gene_analysis_result': 'Normal'}
# TCGA-G4-6315: {'icd_10': 'C18.6', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-G4-6317: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-G4-6320: {'icd_10': 'C18.3', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6321: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6322: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.6', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-G4-6323: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6586: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6588: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6625: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6626: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6627: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-G4-6628: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-NH-A50T: {'icd_10': 'C18.5', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-NH-A50U: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-NH-A50V: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-NH-A5IV: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-NH-A6GA: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-NH-A6GB: {'icd_10': 'C18.4', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-NH-A6GC: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.6', 'histological_type': 'Colon Mucinous Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-NH-A8F7: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-NH-A8F8: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'YES', 'kras_mutation_codon': 12.0}
# TCGA-QG-A5YV: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-QG-A5YW: {'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}
# TCGA-QG-A5YX: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-QG-A5Z1: {'icd_10': 'C19', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-QG-A5Z2: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-QL-A97D: {'icd_10': 'C18.2', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-RU-A8FL: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma', 'kras_mutation_found': 'NO'}
# TCGA-SS-A7HO: {'icd_10': 'C18.0', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-T9-A92H: {'icd_10': 'C18.7', 'histological_type': 'Colon Adenocarcinoma'}
# TCGA-WS-AB45: {'icd_o_3_histology': '8480/3', 'icd_10': 'C18.0', 'histological_type': 'Colon Mucinous Adenocarcinoma'}

# %%
no_matches = [] # 일치하는 항목이 두개 미만인 샘플 쌍 저장하는 리스트
matching_sametype_pairs = [] # 두 개 이상의 일치 항목을 가진 샘플 쌍을 별도로 저장함 (나중에 비교위해)

# 각샘플끼리 모두 비교
for (i1, row1), (i2, row2) in combinations(row_sets.items(), 2):
   
    common_items = set(row1.items()) & set(row2.items())
    
    
    num_matches = len(common_items)
    
    if num_matches >= 2:
        common_values = {k: v for k, v in common_items}
        matching_sametype_pairs.append((i1, i2))
    elif num_matches == 0 :
        no_matches.append((i1, i2))

# %%
print("2개이상 (같은 서브타입) :", len(matching_sametype_pairs))
print("2개미만 (다른 서브타입) :",len(no_matches))
# Out:
# 2개이상 (같은 서브타입) : 14090
# 2개미만 (다른 서브타입) : 22649

# %%
# 피클에서 불러와서 네트워크 만들고 확인
with open('/home/lee/home/pizzz&pkl/use_pkl/pcc0.3_sil0.4_th0.1_pvalue0.05_COAD.pkl', 'rb') as f:
    results = pickle.load(f)

print("Results loaded from clustering_results.pkl")

# 불러온 results를 사용하여 네트워크 구축 
G = nx.Graph()
for combo, result in results:
    if result is not None:
        for sample in result:
            # 샘플 이름을 12글자로 자름 (클리닉과 비교하기 위함)
            trimmed_samples = [s[:12] for s in sample[1]] 
            G.add_edge(combo[0], combo[1], sample=trimmed_samples)


#자카드를 구하기 위해 각 샘플별 네트워크에서 어떤 gene을 갖고있는지를 나눔
sample_to_genes = {}
for u, v, data in G.edges(data=True):
    for sample in data['sample']:
        if sample not in sample_to_genes:
            sample_to_genes[sample] = set()
        sample_to_genes[sample].add(u)
        sample_to_genes[sample].add(v)
# Out:
# Results loaded from clustering_results.pkl

# %%
# 자카드 계수 계산 함수
def jaccard_index(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union != 0 else 0

# 자카드 계수 계산
sametype_jaccard = []
for pair in matching_sametype_pairs:
    try:
        set1 = sample_to_genes[pair[0]]
        set2 = sample_to_genes[pair[1]]
        jaccard = jaccard_index(set1, set2)
        sametype_jaccard.append(jaccard)
    except KeyError as e:#이거는 clinic에서는 있는 쌍인데, 우리가 구축한 네트워크엔 그 쌍이 없어서 출력되는 예외처리
        print(f"KeyError for pair {pair}: {e}") 

differenttype_jaccard = []
for pair in no_matches:
    try:
        set1 = sample_to_genes[pair[0]]
        set2 = sample_to_genes[pair[1]]
        jaccard = jaccard_index(set1, set2)
        differenttype_jaccard.append(jaccard)
    except KeyError as e:
        print(f"KeyError for pair {pair}: {e}")
# Out:
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-2671'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-2675'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-3807'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-5656'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-5667'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-6142'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-6652'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-A567'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-A56B'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3509'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3521'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3524'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3526'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3529'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3531'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3538'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3542'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3558'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3560'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3655'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3678'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3693'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3696'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3812'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3846'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3848'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3860'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3867'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3968'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3972'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3977'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3979'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3984'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A004'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00F'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00K'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00O'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00Q'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00W'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00Z'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A017'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01F'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01I'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01K'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01S'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01T'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01X'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A02F'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A02H'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A02J'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A02W'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A03J'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AM-5821'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AU-3779'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AY-A8YK'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AZ-4308'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AZ-6601'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AZ-6603'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AZ-6607'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AZ-6608'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CA-6715'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-4947'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-4948'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-5914'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-5915'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-4746'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-5341'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-5344'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-5868'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6161'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6163'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6164'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6165'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6172'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6676'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6678'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6679'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-5541'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6532'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6920'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6922'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6923'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6924'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6926'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6927'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A1D0'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A1DB'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A28C'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A28E'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A28F'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6459'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6460'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6806'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6808'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6809'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6854'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6855'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6303'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6307'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6309'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6317'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6625'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-NH-A8F7'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-QG-A5YV'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-QG-A5YX'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-T9-A92H'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2671', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-2675', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-3807', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-5656', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-5667', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-6142', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-6652', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-A567', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-A56B', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3509', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3521', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3524', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3526', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3529', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3531', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3538', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3542', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3560'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3655'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3678'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3693'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3696'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3812'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3846'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3848'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3860'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3867'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3968'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3972'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3977'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3979'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3984'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A004'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00F'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00K'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00O'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00Q'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00W'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00Z'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A017'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01F'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01I'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01K'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01S'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01T'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01X'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A02F'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A02H'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A02J'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A02W'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A03J'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AM-5821'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AU-3779'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AY-A8YK'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AZ-4308'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AZ-6601'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AZ-6603'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AZ-6607'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AZ-6608'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CA-6715'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-4947'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-4948'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-5914'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-5915'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-4746'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-5341'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-5344'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-5868'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6161'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6163'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6164'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6165'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6172'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6676'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6678'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6679'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-5541'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6532'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6920'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6922'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6923'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6924'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6926'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6927'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A1D0'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A1DB'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A28C'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A28E'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A28F'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6459'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6460'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6806'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6808'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6809'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6854'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6855'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6303'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6307'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6309'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6317'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6625'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-NH-A8F7'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-QG-A5YV'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-QG-A5YX'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-T9-A92H'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-4T-AA8H', 'TCGA-A6-2670'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-4T-AA8H', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-4T-AA8H', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-3809'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-6780'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-6781'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-A565'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-A6-A566'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3516'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3543'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3555'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3684'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3692'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3821'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3837'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3852'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3854'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3877'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3947'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3949'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3950'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3966'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-3994'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00J'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A00N'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01D'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01G'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A01R'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A024'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AA-A03F'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AD-5900'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AD-6899'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-AY-6196'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CA-5796'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CA-6717'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-4950'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-4951'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-4952'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CK-6751'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-4748'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-5863'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-CM-6162'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-5539'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6534'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6540'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6928'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-6930'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-D5-7000'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A1D6'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A1HB'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A280'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A285'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A288'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-DM-A28K'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6463'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-F4-6856'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6302'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-G4-6322'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-NH-A50U'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-NH-A6GC'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-QG-A5YW'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2670', 'TCGA-WS-AB45'): 'TCGA-A6-2670'
# KeyError for pair ('TCGA-A6-2674', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-3809', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-3809', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-6780', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-6780', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-6781', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-6781', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-A565', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-A565', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-A6-A566', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-A6-A566', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3516', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3516', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3543', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3543', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3555', 'TCGA-AA-3558'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3555', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3556', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3684'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3692'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3821'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3837'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3852'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3854'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3877'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3947'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3949'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3950'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3966'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-3994'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00J'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A00N'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01D'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01G'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A01R'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A024'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AA-A03F'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AD-5900'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AD-6899'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-AY-6196'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CA-5796'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CA-6717'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-4950'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-4951'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-4952'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CK-6751'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-4748'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-5863'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-CM-6162'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-5539'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6534'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6540'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6928'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-6930'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-D5-7000'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A1D6'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A1HB'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A280'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A285'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A288'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-DM-A28K'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6463'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-F4-6856'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6302'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-G4-6322'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-NH-A50U'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-NH-A6GC'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-QG-A5YW'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3558', 'TCGA-WS-AB45'): 'TCGA-AA-3558'
# KeyError for pair ('TCGA-AA-3684', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3692', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3821', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3837', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3852', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3854', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3877', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3947', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3949', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3950', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3966', 'TCGA-AA-3967'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-3994'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A00J'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A00N'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A01D'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A01G'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A01R'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A024'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AA-A03F'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AD-5900'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AD-6899'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AY-4071'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-AY-6196'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CA-5796'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CA-6717'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CK-4950'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CK-4951'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CK-4952'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CK-6748'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CK-6751'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CM-4748'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CM-5863'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-CM-6162'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-5539'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-6534'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-6540'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-6928'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-6930'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-D5-7000'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A0XF'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A1D6'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A1D7'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A1HB'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A280'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A285'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A288'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-DM-A28K'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-F4-6463'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-F4-6704'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-F4-6856'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-G4-6302'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-G4-6322'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-NH-A50U'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-NH-A6GC'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-QG-A5YW'): 'TCGA-AA-3967'
# KeyError for pair ('TCGA-AA-3967', 'TCGA-WS-AB45'): 'TCGA-AA-3967'

# %%
print("같은 서브타입 개수 :", len(sametype_jaccard))
print("다른 서브타입 개수 :",len(differenttype_jaccard))
# Out:
# 같은 서브타입 개수 : 13879
# 다른 서브타입 개수 : 22462

# %%
import random

random.seed(42) 

#개수를 맞추기 위해 471863개에서 66696개만 랜덤으로 뽑았음
differenttype_jaccard = random.sample(differenttype_jaccard, min(13879, len(differenttype_jaccard)))


print("같은 네트워크 개수 :", len(sametype_jaccard))
print("다른 네트워크 개수 :",len(differenttype_jaccard))
# Out:
# 같은 네트워크 개수 : 13879
# 다른 네트워크 개수 : 13879

# %%
import scipy.stats as stats

# 정규성 검정
stat1, p_value1 = stats.shapiro(sametype_jaccard)
stat2, p_value2 = stats.shapiro(differenttype_jaccard)

print("Shapiro-Wilk Test:")
print(f"sametype_jaccard - Statistic: {stat1:.3f}, P-value: {p_value1:.3f}")
print(f"differenttype_jaccard - Statistic: {stat2:.3f}, P-value: {p_value2:.3f}")

print('\n')


# wilcoxon's Test 수행
stat, p_value = stats.wilcoxon(sametype_jaccard, differenttype_jaccard)

print("wilcoxon Test:")
print(f"Statistic: {stat:.3f}")
print(f"P-value: {p_value:.3f}")  # 이때 0.05 미만이면 분산이 동일하지 않음을 의미한다.

print('\n')
# Out:
# Shapiro-Wilk Test:
# sametype_jaccard - Statistic: 0.990, P-value: 0.000
# differenttype_jaccard - Statistic: 0.988, P-value: 0.000
#
#
# wilcoxon Test:
# Statistic: 38200823.000
# P-value: 0.000
# /BiO/lee/woody/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 13879.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Levene's Test 수행
stat, p_value = stats.levene(sametype_jaccard, differenttype_jaccard)

print("Levene's Test(분산의 동질성을 확인하는 검정통계량):")
print(f"Statistic: {stat:.3f}")
print(f"P-value: {p_value:.3f}")  # 이때 0.05 미만이면 분산이 동일하지 않음을 의미한다.

print('\n')
# 분산이 동일하지 않은 경우 t-test 수행
if p_value < 0.05:
    print("Variances are not equal. Performing Welch's t-test.")
    t_stat, p_value = stats.ttest_ind(sametype_jaccard, differenttype_jaccard, equal_var=False)
else:
    print("Variances are equal. Performing standard t-test.")
    t_stat, p_value = stats.ttest_ind(sametype_jaccard, differenttype_jaccard)

print("2-sample t-test result:")
print(f"t-statistic: {t_stat:.3f}")
print(f"p-value: {p_value:.3f}")
# Out:
# Levene's Test(분산의 동질성을 확인하는 검정통계량):
# Statistic: 0.048
# P-value: 0.826
#
#
# Variances are equal. Performing standard t-test.
# 2-sample t-test result:
# t-statistic: -1.557
# p-value: 0.120

# %%
# 그래프 크기 설정
plt.figure(figsize=(14, 9))

# 서로 다른 서브타입 간 자카드 인덱스 히스토그램 추가
sns.histplot(sametype_jaccard, bins=20, kde=True, color='red', label='Between same Subtypes')
sns.histplot(differenttype_jaccard, bins=20, kde=True, color='blue', label='Between Different Subtypes')

# 0.5 축에 세로선 추가
#plt.axvline(x=0.5, color='black', linestyle='--', linewidth=2)

plt.xlim(0.1, 0.9)
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title('different subtype matches < 2')
plt.xlabel('Jaccard Index')
plt.ylabel('Count')
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')

# 범례를 그래프 안으로 이동
plt.legend( loc='upper right', bbox_to_anchor=(0.95, 0.95), borderaxespad=0.)
# p-value 텍스트 추가
p_value_text = f'Wilcoxon p-value: {p_value:.3f}'
plt.text(0.01, max(plt.gca().get_ylim())*0.95, p_value_text, fontsize=12, color='black', bbox=dict(facecolor='white', alpha=0.5))

plt.show()

# %%
# 데이터를 딕셔너리로 구성
data_to_save = {
    "sametype_jaccard": sametype_jaccard,
    "differenttype_jaccard": differenttype_jaccard
}

# 피클 파일로 저장
with open('COAD_jaccard_data.pkl', 'wb') as f:
    pickle.dump(data_to_save, f)
